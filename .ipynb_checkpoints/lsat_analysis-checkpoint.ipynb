# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import glob

score_files = glob.glob('*.txt')
Q,S,scores=[],[],[]

# read question types
question_types = {}
with open('index/question_type.txt', 'r') as f:
    for line in f.readlines():
        l = line.strip().split(',')
        question_types[l[0]] = l[1]

# read score files
for i, score_file in enumerate(score_files):        
    Q.append({})
    S.append({})
    
    with open(score_file, 'r') as f:
        for line in f.readlines():
            l=line.strip()
            if not l: continue

            sp = l.split(',')    
            # score is the header
            if len(sp) == 1:
                scores.append(int(sp[0]))
            else:
                if sp[1] not in Q[i]:
                    Q[i][sp[1]] = 0
                    S[i][sp[1]] = 0

                Q[i][sp[1]] += 1
                S[i][sp[1]] += int(sp[2])

# %% [markdown]
# Individual test report
# ============
# Each prep test is broken down by question type and the number of correct answers are reported.

# %%
#change default figure size
from pylab import rcParams
rcParams['figure.figsize'] = 10, 5
width = 0.35  

for i, score_file in enumerate(score_files):
    fig, ax = plt.subplots()
    y = []
    x1 = []
    x2 = []

    for key in Q[i]:
        y.append(question_types[key])
        x1.append(Q[i][key])
        x2.append(S[i][key])

    ind = np.arange(len(x1))    

    r1 = ax.barh(ind, x1, width, color='green')
    r2 = ax.barh(ind, x2, width, color='yellow')
    ax.set_title('Prep test: %s, Score: %d' % (score_files[i].split('.')[0], scores[i]))
    ax.set_xlabel('Number of questions')
    ax.set_yticks(ind)
    ax.set_yticklabels(y)
    ax.legend( (r1[0], r2[0]), ('Total', 'Correct'),bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0. )
    plt.show()

# %% [markdown]
# Overall performance on each question category
# ========================
# This graph provides an aggregated view using data from all the prep tests.

# %%
total_Q = {}
total_S = {}
perc = {}

# enumerate over all exams
for i, score_file in enumerate(score_files):
    for key in Q[i]:
        if not key in total_Q:
            total_Q[key] = 0
            total_S[key] = 0
            
        total_Q[key] += Q[i][key]
        total_S[key] += S[i][key]
        
fig, ax = plt.subplots()
y,x1,x2 = [],[],[]

for key in total_Q:
    y.append(question_types[key])
    x1.append(total_Q[key])
    x2.append(total_S[key])
    perc[key] = total_S[key] / float(total_Q[key])

ind = np.arange(len(x1))    

r1 = ax.barh(ind, x1, width, color='green')
r2 = ax.barh(ind, x2, width, color='yellow')
ax.set_title('Aggregated view')
ax.set_xlabel('Number of questions')
ax.set_yticks(ind)
ax.set_yticklabels(y)
ax.legend( (r1[0], r2[0]), ('Total', 'Correct'),bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0. )
plt.show()

# %% [markdown]
# Weakest areas (by percentage)
# ================

# %%
import operator
for w in sorted(perc, key=perc.get):
  print question_types[w], perc[w]
# Out:
# LR Paradox 0.571428571429
# RC Logic Function 0.636363636364
# LR Role of a statement 0.666666666667
# LR Principle 0.695652173913
# AR Must be false 0.7
# AR Must be true 0.714285714286
# LR Flaw 0.74358974359
# RC Miscellaneous 0.75
# RC Logic Reasoning 0.777777777778
# LR Assumption 0.8
# RC Inference 0.8
# AR Could be true 0.8
# LR Strengthen 0.8
# AR If/Could be true 0.818181818182
# AR Min/max 0.818181818182
# LR Point at issue 0.857142857143
# AR Miscellaneous 0.857142857143
# LR Weaken 0.862068965517
# RC Detail 0.869565217391
# LR Parallel Reasoning 0.875
# LR Inference 0.891891891892
# LR Method of argument 0.9
# AR If/must be true 0.909090909091
# LR Main point 0.923076923077
# RC Global 0.96875
# AR Completely determine 1.0
# AR Acceptability 1.0
# LR Miscellaneous 1.0
# AR If clause/complete and accurate list 1.0
# AR Partial acceptability 1.0
# AR Rule substitution 1.0
